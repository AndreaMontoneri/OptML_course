# %%
# Useful starting lines
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Solving Fixed Point Problems
#
# In numerous applications, we encounter the task of solving equations of the form $$x = g(x)$$
# for a continuous function $g$. In this exercise we will see one simple method to solve such problems: $$x_{t+1} = g(x_t)\,.$$
# We will solve two equations of this form: $$x = log(1+x)$$ and $$x = log(2+x)\,.$$

# %% [markdown]
# ## Plot $g$

# %% [markdown]
# Let us see how the two functions look over an interval $[0,2]$.

# %%
x = np.arange(-0.1, 2, 0.0001)
"""Compute the value of g(x)."""
# ***************************************************
# INSERT YOUR CODE HERE
# TODO: compute the values of log(1+x) and log(2+x)
# ***************************************************
y1 = np.log( 1 + x )
y2 = np.log( 2 + x )

"""Plot the computed values"""
fig = plt.figure()
plt.plot(x, x, label='x')
plt.plot(x, y1, label='$log(1 + x)$')
plt.plot(x, y2, label='$log(2 + x)$')
plt.grid(linestyle=':')
plt.axhline(0, color='black')
plt.axvline(0, color='black')
plt.legend()
plt.show()

# %% [markdown]
# ## Compute Lipschitz Constant of $g$
#
# Derive and plot the derivate of $\log(1+x)$ and $\log(2+x)$ over the interval $[0,2]$. What are the Lipschitz constants?

# %%
x = np.arange(-0.1, 2, 0.0001)

"""Compute the derivative of g(x)."""
# ***************************************************
# INSERT YOUR CODE HERE
# TODO: compute the derivatives of log(1+x) and log(2+x)
# ***************************************************
y1 = 1 / ( 1 + x )
y2 = 1 / ( 2 + x )

"""Plot the computed values"""
fig = plt.figure()
plt.plot(x, y1, label='$log(1 + x)$')
plt.plot(x, y2, label='$log(2 + x)$')
plt.grid(linestyle=':')
plt.axhline(0, color='black')
plt.axvline(0, color='black')
plt.legend()
plt.show()

# %% [markdown]
# ## Computing Fixed Point

# %% [markdown]
# Please fill in the functions `compute_gradient` below:

# %%
def fixed_point(initial_x, max_iters, objective):
    """Compute the fixed point."""
    # Define parameters to store x and objective func. values
    xs = []
    errors = []
    x = initial_x
    for n_iter in range(max_iters):
        # compute objective and error
        obj = objective(x)
        error = np.abs(x - obj)
        # store x and error
        xs.append(x)
        errors.append(error)
        
        # update x
        
        # ***************************************************
        # INSERT YOUR CODE HERE
        # TODO: compute the update
        # ***************************************************
        x = obj
        
        # print the current error
        if n_iter % 10 == 0: 
            print("Fixed point: iteration ={i}, x = {x:.2e}, error={err:.2e}".format(i=n_iter, x=x, err=error))
    return errors, xs

# %% [markdown]
# Test your implementation on the first function. Does it converge to 0?

# %%
# Define the parameters of the algorithm.
max_iters = 100

# Write the objective function
func = lambda x: np.log(1 + x)

# Initialization
initial_x = 1

# Run fixed point.
errors_func1, xs_func1 = fixed_point(initial_x, max_iters, func)
# Out:
# Fixed point: iteration =0, x = 6.93e-01, error=3.07e-01
# Fixed point: iteration =10, x = 1.61e-01, error=1.37e-02
# Fixed point: iteration =20, x = 9.00e-02, error=4.17e-03
# Fixed point: iteration =30, x = 6.23e-02, error=1.98e-03
# Fixed point: iteration =40, x = 4.76e-02, error=1.15e-03
# Fixed point: iteration =50, x = 3.85e-02, error=7.51e-04
# Fixed point: iteration =60, x = 3.23e-02, error=5.28e-04
# Fixed point: iteration =70, x = 2.78e-02, error=3.91e-04
# Fixed point: iteration =80, x = 2.45e-02, error=3.01e-04
# Fixed point: iteration =90, x = 2.18e-02, error=2.39e-04

# %% [markdown]
# Run your implementation on the second function

# %%
# Define the parameters of the algorithm.
max_iters = 100

# Write the second objective function
func = lambda x: np.log(2 + x)

# Initialization
initial_x = 1

# Run fixed point.
errors_func2, xs_func2 = fixed_point(initial_x, max_iters, func)
# Out:
# Fixed point: iteration =0, x = 1.10e+00, error=9.86e-02
# Fixed point: iteration =10, x = 1.15e+00, error=1.09e-06
# Fixed point: iteration =20, x = 1.15e+00, error=1.14e-11
# Fixed point: iteration =30, x = 1.15e+00, error=0.00e+00
# Fixed point: iteration =40, x = 1.15e+00, error=0.00e+00
# Fixed point: iteration =50, x = 1.15e+00, error=0.00e+00
# Fixed point: iteration =60, x = 1.15e+00, error=0.00e+00
# Fixed point: iteration =70, x = 1.15e+00, error=0.00e+00
# Fixed point: iteration =80, x = 1.15e+00, error=0.00e+00
# Fixed point: iteration =90, x = 1.15e+00, error=0.00e+00

# %% [markdown]
# **Plotting error values**

# %%
plt.semilogy()
plt.xlabel('Number of steps')
plt.ylabel('Value of Error')
plt.yscale("log")
plt.plot(range(len(errors_func1)), errors_func1, label='$log(1 + x)$')
plt.plot(range(len(errors_func2)), errors_func2, label='$log(2 + x)$')
plt.grid()
plt.legend()
plt.show()

# %% [markdown]
# What do you observe about the rates of convergence of the two methods? Can you explain this difference?
#
# Repeat the experiment with different starting points. Try also with $x=sin(x)$, $x = sin(x+1)$, and $x = sin(x+2)$. How about other functions?

# %% [markdown]
# # Difference

# %% [markdown]
# - For the first function we converge way slower than for the second one. Maybe because the fixed point is close to the strating point.

# %% [markdown]
# # ≠ $X_0$

# %%
max_iters = 100
initial_x = -0.1

func = lambda x: np.log(1 + x)
errors_func1, xs_func1 = fixed_point(initial_x, max_iters, func)

func = lambda x: np.log(2 + x)
errors_func2, xs_func2 = fixed_point(initial_x, max_iters, func)

plt.semilogy()
plt.xlabel('Number of steps')
plt.ylabel('Value of Error')
plt.yscale("log")
plt.plot(range(len(errors_func1)), errors_func1, label='$log(1 + x)$')
plt.plot(range(len(errors_func2)), errors_func2, label='$log(2 + x)$')
plt.grid()
plt.legend()
plt.show()
# Out:
# Fixed point: iteration =0, x = -1.05e-01, error=5.36e-03
# Fixed point: iteration =10, x = -2.29e-01, error=2.44e-02
# Fixed point: iteration =20, x = nan, error=nan
# Fixed point: iteration =30, x = nan, error=nan
# Fixed point: iteration =40, x = nan, error=nan
# Fixed point: iteration =50, x = nan, error=nan
# Fixed point: iteration =60, x = nan, error=nan
# Fixed point: iteration =70, x = nan, error=nan
# Fixed point: iteration =80, x = nan, error=nan
# Fixed point: iteration =90, x = nan, error=nan
# Fixed point: iteration =0, x = 6.42e-01, error=7.42e-01
# Fixed point: iteration =10, x = 1.15e+00, error=1.29e-05
# Fixed point: iteration =20, x = 1.15e+00, error=1.36e-10
# Fixed point: iteration =30, x = 1.15e+00, error=1.55e-15
# Fixed point: iteration =40, x = 1.15e+00, error=0.00e+00
# Fixed point: iteration =50, x = 1.15e+00, error=0.00e+00
# Fixed point: iteration =60, x = 1.15e+00, error=0.00e+00
# Fixed point: iteration =70, x = 1.15e+00, error=0.00e+00
# Fixed point: iteration =80, x = 1.15e+00, error=0.00e+00
# Fixed point: iteration =90, x = 1.15e+00, error=0.00e+00
# /var/folders/5m/jt5tz_3919j_zzpx7yxvs4bm0000gn/T/ipykernel_91475/3582488632.py:4: RuntimeWarning: invalid value encountered in log
#   func = lambda x: np.log(1 + x)

# %%
max_iters = 100
initial_x = 0

func = lambda x: np.log(1 + x)
errors_func1, xs_func1 = fixed_point(initial_x, max_iters, func)

func = lambda x: np.log(2 + x)
errors_func2, xs_func2 = fixed_point(initial_x, max_iters, func)

plt.semilogy()
plt.xlabel('Number of steps')
plt.ylabel('Value of Error')
plt.yscale("log")
plt.plot(range(len(errors_func1)), errors_func1, label='$log(1 + x)$')
plt.plot(range(len(errors_func2)), errors_func2, label='$log(2 + x)$')
plt.grid()
plt.legend()
plt.show()
# Out:
# Fixed point: iteration =0, x = 0.00e+00, error=0.00e+00
# Fixed point: iteration =10, x = 0.00e+00, error=0.00e+00
# Fixed point: iteration =20, x = 0.00e+00, error=0.00e+00
# Fixed point: iteration =30, x = 0.00e+00, error=0.00e+00
# Fixed point: iteration =40, x = 0.00e+00, error=0.00e+00
# Fixed point: iteration =50, x = 0.00e+00, error=0.00e+00
# Fixed point: iteration =60, x = 0.00e+00, error=0.00e+00
# Fixed point: iteration =70, x = 0.00e+00, error=0.00e+00
# Fixed point: iteration =80, x = 0.00e+00, error=0.00e+00
# Fixed point: iteration =90, x = 0.00e+00, error=0.00e+00
# Fixed point: iteration =0, x = 6.93e-01, error=6.93e-01
# Fixed point: iteration =10, x = 1.15e+00, error=1.15e-05
# Fixed point: iteration =20, x = 1.15e+00, error=1.21e-10
# Fixed point: iteration =30, x = 1.15e+00, error=1.33e-15
# Fixed point: iteration =40, x = 1.15e+00, error=0.00e+00
# Fixed point: iteration =50, x = 1.15e+00, error=0.00e+00
# Fixed point: iteration =60, x = 1.15e+00, error=0.00e+00
# Fixed point: iteration =70, x = 1.15e+00, error=0.00e+00
# Fixed point: iteration =80, x = 1.15e+00, error=0.00e+00
# Fixed point: iteration =90, x = 1.15e+00, error=0.00e+00

# %%
max_iters = 100
initial_x = 10

func = lambda x: np.log(1 + x)
errors_func1, xs_func1 = fixed_point(initial_x, max_iters, func)

func = lambda x: np.log(2 + x)
errors_func2, xs_func2 = fixed_point(initial_x, max_iters, func)

plt.semilogy()
plt.xlabel('Number of steps')
plt.ylabel('Value of Error')
plt.yscale("log")
plt.plot(range(len(errors_func1)), errors_func1, label='$log(1 + x)$')
plt.plot(range(len(errors_func2)), errors_func2, label='$log(2 + x)$')
plt.grid()
plt.legend()
plt.show()
# Out:
# Fixed point: iteration =0, x = 2.40e+00, error=7.60e+00
# Fixed point: iteration =10, x = 1.99e-01, error=2.12e-02
# Fixed point: iteration =20, x = 1.01e-01, error=5.26e-03
# Fixed point: iteration =30, x = 6.73e-02, error=2.32e-03
# Fixed point: iteration =40, x = 5.05e-02, error=1.30e-03
# Fixed point: iteration =50, x = 4.04e-02, error=8.26e-04
# Fixed point: iteration =60, x = 3.36e-02, error=5.72e-04
# Fixed point: iteration =70, x = 2.88e-02, error=4.19e-04
# Fixed point: iteration =80, x = 2.52e-02, error=3.20e-04
# Fixed point: iteration =90, x = 2.24e-02, error=2.53e-04
# Fixed point: iteration =0, x = 2.48e+00, error=7.52e+00
# Fixed point: iteration =10, x = 1.15e+00, error=2.33e-05
# Fixed point: iteration =20, x = 1.15e+00, error=2.45e-10
# Fixed point: iteration =30, x = 1.15e+00, error=2.66e-15
# Fixed point: iteration =40, x = 1.15e+00, error=0.00e+00
# Fixed point: iteration =50, x = 1.15e+00, error=0.00e+00
# Fixed point: iteration =60, x = 1.15e+00, error=0.00e+00
# Fixed point: iteration =70, x = 1.15e+00, error=0.00e+00
# Fixed point: iteration =80, x = 1.15e+00, error=0.00e+00
# Fixed point: iteration =90, x = 1.15e+00, error=0.00e+00

# %% [markdown]
# # sin(x) / sin(x+1) / sin(x+2)

# %%
max_iters = 100
initial_x = 1

func = lambda x: np.sin(x)
errors_func1, xs_func1 = fixed_point(initial_x, max_iters, func)

func = lambda x: np.sin(x+1)
errors_func2, xs_func2 = fixed_point(initial_x, max_iters, func)

func = lambda x: np.sin(x+2)
errors_func3, xs_func3 = fixed_point(initial_x, max_iters, func)

plt.semilogy()
plt.xlabel('Number of steps')
plt.ylabel('Value of Error')
plt.yscale("log")
plt.plot(range(len(errors_func1)), errors_func1, label='$sin(x)$')
plt.plot(range(len(errors_func2)), errors_func2, label='$sin(x+1)$')
plt.plot(range(len(errors_func3)), errors_func3, label='$sin(x+2)$')
plt.grid()
plt.legend()
plt.show()
# Out:
# Fixed point: iteration =0, x = 8.41e-01, error=1.59e-01
# Fixed point: iteration =10, x = 4.47e-01, error=1.64e-02
# Fixed point: iteration =20, x = 3.44e-01, error=7.17e-03
# Fixed point: iteration =30, x = 2.90e-01, error=4.25e-03
# Fixed point: iteration =40, x = 2.56e-01, error=2.89e-03
# Fixed point: iteration =50, x = 2.32e-01, error=2.13e-03
# Fixed point: iteration =60, x = 2.13e-01, error=1.65e-03
# Fixed point: iteration =70, x = 1.99e-01, error=1.33e-03
# Fixed point: iteration =80, x = 1.87e-01, error=1.10e-03
# Fixed point: iteration =90, x = 1.77e-01, error=9.31e-04
# Fixed point: iteration =0, x = 9.09e-01, error=9.07e-02
# Fixed point: iteration =10, x = 9.35e-01, error=3.05e-06
# Fixed point: iteration =20, x = 9.35e-01, error=9.92e-11
# Fixed point: iteration =30, x = 9.35e-01, error=3.33e-15
# Fixed point: iteration =40, x = 9.35e-01, error=0.00e+00
# Fixed point: iteration =50, x = 9.35e-01, error=0.00e+00
# Fixed point: iteration =60, x = 9.35e-01, error=0.00e+00
# Fixed point: iteration =70, x = 9.35e-01, error=0.00e+00
# Fixed point: iteration =80, x = 9.35e-01, error=0.00e+00
# Fixed point: iteration =90, x = 9.35e-01, error=0.00e+00
# Fixed point: iteration =0, x = 1.41e-01, error=8.59e-01
# Fixed point: iteration =10, x = 5.00e-01, error=1.19e-01
# Fixed point: iteration =20, x = 5.46e-01, error=1.89e-02
# Fixed point: iteration =30, x = 5.53e-01, error=3.03e-03
# Fixed point: iteration =40, x = 5.54e-01, error=4.83e-04
# Fixed point: iteration =50, x = 5.54e-01, error=7.72e-05
# Fixed point: iteration =60, x = 5.54e-01, error=1.23e-05
# Fixed point: iteration =70, x = 5.54e-01, error=1.97e-06
# Fixed point: iteration =80, x = 5.54e-01, error=3.14e-07
# Fixed point: iteration =90, x = 5.54e-01, error=5.02e-08
