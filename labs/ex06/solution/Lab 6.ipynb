# %%
import matplotlib.pyplot as plt
import numpy as np
import torch
from helper import (
    generate_dataset,
    predict_grid,
    visualize_datasets,
    visualize_one_dataset,
    visualize_predictions,
)
from torch.utils import data

# %% [markdown]
# # Generate data
#
# We provide a helper function which generates artificial datasets

# %%
NUM_SAMPLES = 100

blobs_train, blobs_test = generate_dataset("blobs", NUM_SAMPLES)
moons_train, moons_test = generate_dataset("moons", NUM_SAMPLES)
xor_train, xor_test = generate_dataset("xor", NUM_SAMPLES)
squares_train, squares_test = generate_dataset("bar", NUM_SAMPLES)

# The generate_dataset function returns PyTorch dataset objects
type(blobs_train), type(blobs_test)
# Out:
# (torch.utils.data.dataset.Subset, torch.utils.data.dataset.Subset)

# %% [markdown]
# Let us plot the train and the test data sets. Note the differences between the two.

# %%
datasets = [
    ("Blobs", blobs_train, blobs_test),
    ("Moons", moons_train, moons_test),
    ("Bar", squares_train, squares_test),
    ("XOR", xor_train, xor_test)
]

visualize_datasets(datasets)

# %% [markdown]
# # Optimizing using PyTorch
#
# Write an optimizer in PyTorch by taking using its default SGD class

# %%
def optimize(train_data, test_data, model, loss_fn = torch.nn.CrossEntropyLoss(), lr = 0.1, momentum = 0.0):
    """
    Stochastic Gradient Descent optimizer
    
    :param train_data: torch.utils.data.dataset.Subset
    :param test_data: torch.utils.data.dataset.Subset
    :param model: torch.nn.Module (see https://pytorch.org/docs/stable/nn.html)
    :param loss_fn: torch.nn.modules.loss (see https://pytorch.org/docs/stable/nn.html#id51)
    :param lr: float, learning rate
    
    :return:
    - objectives, a list of loss values on the test dataset, collected at the end of each pass over the dataset (epoch)
    """
    # defatult pytorch functions which are useful for loading testing and training data
    train_loader = data.DataLoader(train_data, batch_size=10, shuffle=True)
    test_loader = data.DataLoader(test_data, batch_size=NUM_SAMPLES)
    losses = []
        
    # ***************************************************
    # INSERT YOUR CODE HERE
    # TODO: Define SGD optimizer with learning rate = lr
    # HINT: Use torch.optim.SGD and model.parameters()
    # ***************************************************
    optimizer = torch.optim.SGD(model.parameters(), lr=lr, momentum=momentum)
    
    # Run SGD
    for epoch in range(1000):
        for minibatch, label in train_loader:
            
            optimizer.zero_grad() # Sets the previously computed gradients to zero to prevent accumulation
            
            # ***************************************************
            # INSERT YOUR CODE HERE
            # TODO: prediction on minibatch
            # HINT: Use model.forward
            # ***************************************************
            prediction = model.forward(minibatch)
            
            # ***************************************************
            # INSERT YOUR CODE HERE
            # TODO: compute the loss on prediction
            # HINT: Use loss_fn
            # ***************************************************
            loss = loss_fn(prediction, label)
            
            # ***************************************************
            # INSERT YOUR CODE HERE
            # TODO: compute the minibatch gradient
            # HINT: Use loss.backward!
            # ***************************************************
            loss.backward()
            
            # ***************************************************
            # INSERT YOUR CODE HERE
            # TODO: perform an SGD step
            # HINT: Use optimizer.step!
            # ***************************************************
            optimizer.step()
            
        # Compute the test loss
        # we let torch know that we dont intend to call .backward
        with torch.no_grad():
            test_data, test_labels = next(iter(test_loader))  # load the one and only test batch
            
            # ***************************************************
            # INSERT YOUR CODE HERE
            # TODO: compute the test prediction and test loss
            # ***************************************************
            prediction = model.forward(test_data)
            loss = loss_fn(prediction, test_labels)

            losses.append(loss.item())

            # Print the test loss to monitor progress
            if epoch % 100 == 0:
                print(f'epoch : {epoch} -> Test loss = {loss.item():.4f}')
                
    return losses

# %% [markdown]
# # RBF Kernel
#
# An RBF kernel is the most commonly used `out of the box` kernel method for non-linear data. Intuitively, an RBF-kernel blurs the training data and uses this for classification i.e. the individual green and blue points above get blurred to make green and blue regions, which are used to make predictions. A critical parameter `sigma` defines the width of this blurring---large `sigma` results in more blurring.
#
# See [here](https://github.com/epfml/ML_course/blob/master/lectures/07/lecture07b_kernelRidge.pdf) for more information on the `kernel trick` and [here](https://www.cs.huji.ac.il/~shais/Lectures2014/lecture8.pdf) for an indepth mathematical treatment. Here, we will try develop an intuition for the RBF kernel.

# %%
class RadialBasisFunction(torch.nn.Module):
    def __init__(self, sigma=0.1):
        super().__init__()
        self.gamma = 1 / (2 * sigma ** 2)
        self.num_classes = 2
        self.name = 'RBF'
    
    def init_params(self, train_data):
        # data reshaping to do torch broadcasting magic
        data_matrix = train_data.dataset.tensors[0][train_data.indices, :]
        self.data_matrix = data_matrix.t().view(1, *data_matrix.t().shape)
        
        # ***************************************************
        # INSERT YOUR CODE HERE
        # TODO: initialize parameters alpha to 0
        # HINT: use torch.zeros
        # ***************************************************
        zeros = torch.zeros(len(data_matrix), self.num_classes)
        
        self.alpha = torch.nn.Parameter(zeros)

    def forward(self, minibatch):
        minibatch = minibatch.view(*minibatch.shape, 1)
        K = torch.exp(
            -self.gamma * torch.sum((self.data_matrix - minibatch) ** 2, dim=1, keepdim=True)
        ).squeeze()
        return K @ self.alpha

# %% [markdown]
# Try you code on the blobs data set. Your test loss should be around 0.1 by the end.

# %%
rbf_model = RadialBasisFunction(0.5)
rbf_model.init_params(blobs_train)
rbf_blob_losses = optimize(blobs_train, blobs_test, rbf_model)

plt.plot(rbf_blob_losses)
plt.xlabel('Epoch')
plt.ylabel('Test Loss')
plt.show()
# Out:
# epoch : 0 -> Test loss = 0.5659
# epoch : 100 -> Test loss = 0.1611
# epoch : 200 -> Test loss = 0.1442
# epoch : 300 -> Test loss = 0.1272
# epoch : 400 -> Test loss = 0.1474
# epoch : 500 -> Test loss = 0.1306
# epoch : 600 -> Test loss = 0.1379
# epoch : 700 -> Test loss = 0.1411
# epoch : 800 -> Test loss = 0.1574
# epoch : 900 -> Test loss = 0.1490

# %% [markdown]
# Plot the training data points and the predictions made

# %%
ax = plt.gca()
predict_grid(rbf_model, ax)
visualize_one_dataset(blobs_train, ax)

# %% [markdown]
# ## Effect of alpha

# %% [markdown]
# Plot the results while varying the value of alpha in [0.1, 0.5, 1]. What do you observe? Which is the best value?

# %%
rbf_model = RadialBasisFunction(0.1)
visualize_predictions(datasets, rbf_model, optimize)

rbf_model = RadialBasisFunction(0.5)
visualize_predictions(datasets, rbf_model, optimize)

rbf_model = RadialBasisFunction(1)
visualize_predictions(datasets, rbf_model, optimize)
# Out:
# [{"variableName": "datasets", "type": "list", "supportedEngines": ["pandas"], "isLocalVariable": false, "rawType": "builtins.list"}, {"variableName": "rbf_blob_losses", "type": "list", "supportedEngines": ["pandas"], "isLocalVariable": false, "rawType": "builtins.list"}]
# [{"variableName": "datasets", "type": "list", "supportedEngines": ["pandas"], "isLocalVariable": false, "rawType": "builtins.list"}, {"variableName": "rbf_blob_losses", "type": "list", "supportedEngines": ["pandas"], "isLocalVariable": false, "rawType": "builtins.list"}]
# [{"variableName": "datasets", "type": "list", "supportedEngines": ["pandas"], "isLocalVariable": false, "rawType": "builtins.list"}, {"variableName": "rbf_blob_losses", "type": "list", "supportedEngines": ["pandas"], "isLocalVariable": false, "rawType": "builtins.list"}]
# [{"variableName": "datasets", "type": "list", "supportedEngines": ["pandas"], "isLocalVariable": false, "rawType": "builtins.list"}, {"variableName": "rbf_blob_losses", "type": "list", "supportedEngines": ["pandas"], "isLocalVariable": false, "rawType": "builtins.list"}]
# [{"variableName": "datasets", "type": "list", "supportedEngines": ["pandas"], "isLocalVariable": false, "rawType": "builtins.list"}, {"variableName": "rbf_blob_losses", "type": "list", "supportedEngines": ["pandas"], "isLocalVariable": false, "rawType": "builtins.list"}]
# [{"variableName": "datasets", "type": "list", "supportedEngines": ["pandas"], "isLocalVariable": false, "rawType": "builtins.list"}, {"variableName": "rbf_blob_losses", "type": "list", "supportedEngines": ["pandas"], "isLocalVariable": false, "rawType": "builtins.list"}]
# [{"variableName": "datasets", "type": "list", "supportedEngines": ["pandas"], "isLocalVariable": false, "rawType": "builtins.list"}, {"variableName": "rbf_blob_losses", "type": "list", "supportedEngines": ["pandas"], "isLocalVariable": false, "rawType": "builtins.list"}]
# [{"variableName": "datasets", "type": "list", "supportedEngines": ["pandas"], "isLocalVariable": false, "rawType": "builtins.list"}, {"variableName": "rbf_blob_losses", "type": "list", "supportedEngines": ["pandas"], "isLocalVariable": false, "rawType": "builtins.list"}]
# [{"variableName": "datasets", "type": "list", "supportedEngines": ["pandas"], "isLocalVariable": false, "rawType": "builtins.list"}, {"variableName": "rbf_blob_losses", "type": "list", "supportedEngines": ["pandas"], "isLocalVariable": false, "rawType": "builtins.list"}]
# epoch : 800 -> Test loss = 0.0226
# epoch : 900 -> Test loss = 0.0217
# epoch : 0 -> Test loss = 0.8851
# epoch : 100 -> Test loss = 0.0576
# epoch : 200 -> Test loss = 0.0274
# epoch : 300 -> Test loss = 0.0228
# epoch : 400 -> Test loss = 0.0204
# epoch : 500 -> Test loss = 0.0183
# epoch : 600 -> Test loss = 0.0172
# epoch : 700 -> Test loss = 0.0161
# epoch : 800 -> Test loss = 0.0153
# epoch : 900 -> Test loss = 0.0152
# epoch : 0 -> Test loss = 0.7647
# epoch : 100 -> Test loss = 0.3267
# epoch : 200 -> Test loss = 0.5121
# epoch : 300 -> Test loss = 0.5035
# epoch : 400 -> Test loss = 0.5990
# epoch : 500 -> Test loss = 0.5749
# epoch : 600 -> Test loss = 0.6132
# epoch : 700 -> Test loss = 0.6394
# epoch : 800 -> Test loss = 0.6363
# epoch : 900 -> Test loss = 0.7909
# [{"variableName": "datasets", "type": "list", "supportedEngines": ["pandas"], "isLocalVariable": false, "rawType": "builtins.list"}, {"variableName": "grid", "type": "ndarray", "supportedEngines": ["pandas"], "isLocalVariable": false, "rawType": "numpy.ndarray"}, {"variableName": "rbf_blob_losses", "type": "list", "supportedEngines": ["pandas"], "isLocalVariable": false, "rawType": "builtins.list"}, {"variableName": "test_losses", "type": "list", "supportedEngines": ["pandas"], "isLocalVariable": false, "rawType": "builtins.list"}]
# [{"variableName": "datasets", "type": "list", "supportedEngines": ["pandas"], "isLocalVariable": false, "rawType": "builtins.list"}, {"variableName": "grid", "type": "ndarray", "supportedEngines": ["pandas"], "isLocalVariable": false, "rawType": "numpy.ndarray"}, {"variableName": "rbf_blob_losses", "type": "list", "supportedEngines": ["pandas"], "isLocalVariable": false, "rawType": "builtins.list"}, {"variableName": "test_losses", "type": "list", "supportedEngines": ["pandas"], "isLocalVariable": false, "rawType": "builtins.list"}]
# [{"variableName": "datasets", "type": "list", "supportedEngines": ["pandas"], "isLocalVariable": false, "rawType": "builtins.list"}, {"variableName": "grid", "type": "ndarray", "supportedEngines": ["pandas"], "isLocalVariable": false, "rawType": "numpy.ndarray"}, {"variableName": "rbf_blob_losses", "type": "list", "supportedEngines": ["pandas"], "isLocalVariable": false, "rawType": "builtins.list"}, {"variableName": "test_losses", "type": "list", "supportedEngines": ["pandas"], "isLocalVariable": false, "rawType": "builtins.list"}]
# [{"variableName": "datasets", "type": "list", "supportedEngines": ["pandas"], "isLocalVariable": false, "rawType": "builtins.list"}, {"variableName": "grid", "type": "ndarray", "supportedEngines": ["pandas"], "isLocalVariable": false, "rawType": "numpy.ndarray"}, {"variableName": "rbf_blob_losses", "type": "list", "supportedEngines": ["pandas"], "isLocalVariable": false, "rawType": "builtins.list"}, {"variableName": "test_losses", "type": "list", "supportedEngines": ["pandas"], "isLocalVariable": false, "rawType": "builtins.list"}]
# Learning rates to try: [0.1 0.2 0.4 0.8 1.6]
# epoch : 0 -> Test loss = 0.5474
# epoch : 100 -> Test loss = 0.4963
# epoch : 200 -> Test loss = 0.5062
# epoch : 300 -> Test loss = 0.5042
# epoch : 400 -> Test loss = 0.4645
# epoch : 500 -> Test loss = 0.4424
# epoch : 600 -> Test loss = 0.3949
# epoch : 700 -> Test loss = 0.3264
# epoch : 800 -> Test loss = 0.2761
# epoch : 900 -> Test loss = 0.2429
# epoch : 0 -> Test loss = 1.0903
# epoch : 100 -> Test loss = 0.4717
# epoch : 200 -> Test loss = 0.4917
# epoch : 300 -> Test loss = 0.3798
# epoch : 400 -> Test loss = 0.2879
# epoch : 500 -> Test loss = 0.2033
# epoch : 600 -> Test loss = 0.1562
# epoch : 700 -> Test loss = 0.1161
# epoch : 800 -> Test loss = 0.0972
# epoch : 900 -> Test loss = 0.0827
# epoch : 0 -> Test loss = 0.5142
# epoch : 100 -> Test loss = 0.4034
# epoch : 200 -> Test loss = 0.2231
# epoch : 300 -> Test loss = 0.1160
# epoch : 400 -> Test loss = 0.0815
# epoch : 500 -> Test loss = 0.0640
# epoch : 600 -> Test loss = 0.0541
# epoch : 700 -> Test loss = 0.0478
# epoch : 800 -> Test loss = 0.0451
# epoch : 900 -> Test loss = 0.0411
# epoch : 0 -> Test loss = 0.7027
# epoch : 100 -> Test loss = 0.2511
# epoch : 200 -> Test loss = 0.0783
# epoch : 300 -> Test loss = 0.0592
# epoch : 400 -> Test loss = 0.0496
# epoch : 500 -> Test loss = 0.0436
# epoch : 600 -> Test loss = 0.0388
# epoch : 700 -> Test loss = 0.0361
# epoch : 800 -> Test loss = 0.0335
# epoch : 900 -> Test loss = 0.0324
# epoch : 0 -> Test loss = 0.4552
# epoch : 100 -> Test loss = 0.3396
# epoch : 200 -> Test loss = 0.3951
# epoch : 300 -> Test loss = 0.3577
# epoch : 400 -> Test loss = 0.0911
# epoch : 500 -> Test loss = 0.0543
# epoch : 600 -> Test loss = 0.0412
# epoch : 700 -> Test loss = 0.0370
# epoch : 800 -> Test loss = 0.0350
# epoch : 900 -> Test loss = 0.0331
# [{"variableName": "datasets", "type": "list", "supportedEngines": ["pandas"], "isLocalVariable": false, "rawType": "builtins.list"}, {"variableName": "grid", "type": "ndarray", "supportedEngines": ["pandas"], "isLocalVariable": false, "rawType": "numpy.ndarray"}, {"variableName": "rbf_blob_losses", "type": "list", "supportedEngines": ["pandas"], "isLocalVariable": false, "rawType": "builtins.list"}, {"variableName": "test_losses", "type": "list", "supportedEngines": ["pandas"], "isLocalVariable": false, "rawType": "builtins.list"}]
# [{"variableName": "datasets", "type": "list", "supportedEngines": ["pandas"], "isLocalVariable": false, "rawType": "builtins.list"}, {"variableName": "grid", "type": "ndarray", "supportedEngines": ["pandas"], "isLocalVariable": false, "rawType": "numpy.ndarray"}, {"variableName": "rbf_blob_losses", "type": "list", "supportedEngines": ["pandas"], "isLocalVariable": false, "rawType": "builtins.list"}, {"variableName": "test_losses", "type": "list", "supportedEngines": ["pandas"], "isLocalVariable": false, "rawType": "builtins.list"}]
# Learning rates to try: [0.1 0.2 0.4 0.8 1.6]
# epoch : 0 -> Test loss = 0.5273
# epoch : 100 -> Test loss = 0.5214
# epoch : 200 -> Test loss = 0.5019
# epoch : 300 -> Test loss = 0.4609
# epoch : 400 -> Test loss = 0.4081
# epoch : 500 -> Test loss = 0.3593
# epoch : 600 -> Test loss = 0.3034
# epoch : 700 -> Test loss = 0.2594
# epoch : 800 -> Test loss = 0.2224
# epoch : 900 -> Test loss = 0.1850
# epoch : 0 -> Test loss = 0.4506
# epoch : 100 -> Test loss = 0.4606
# epoch : 200 -> Test loss = 0.4640
# epoch : 300 -> Test loss = 0.3979
# epoch : 400 -> Test loss = 0.2953
# epoch : 500 -> Test loss = 0.2195
# epoch : 600 -> Test loss = 0.1602
# epoch : 700 -> Test loss = 0.1235
# epoch : 800 -> Test loss = 0.1025
# epoch : 900 -> Test loss = 0.0865
# epoch : 0 -> Test loss = 2.2187
# epoch : 100 -> Test loss = 0.5016
# epoch : 200 -> Test loss = 0.2799
# epoch : 300 -> Test loss = 0.1391
# epoch : 400 -> Test loss = 0.0957
# epoch : 500 -> Test loss = 0.0721
# epoch : 600 -> Test loss = 0.0627
# epoch : 700 -> Test loss = 0.0565
# epoch : 800 -> Test loss = 0.0499
# epoch : 900 -> Test loss = 0.0466
# epoch : 0 -> Test loss = 0.6314
# epoch : 100 -> Test loss = 0.2532
# epoch : 200 -> Test loss = 0.0908
# epoch : 300 -> Test loss = 0.0574
# epoch : 400 -> Test loss = 0.0491
# epoch : 500 -> Test loss = 0.0422
# epoch : 600 -> Test loss = 0.0382
# epoch : 700 -> Test loss = 0.0355
# epoch : 800 -> Test loss = 0.0332
# epoch : 900 -> Test loss = 0.0313
# epoch : 0 -> Test loss = 0.4138
# epoch : 100 -> Test loss = 0.2068
# epoch : 200 -> Test loss = 0.0569
# epoch : 300 -> Test loss = 0.0442
# epoch : 400 -> Test loss = 0.0383
# epoch : 500 -> Test loss = 0.0343
# epoch : 600 -> Test loss = 0.0320
# epoch : 700 -> Test loss = 0.0295
# epoch : 800 -> Test loss = 0.0284
# epoch : 900 -> Test loss = 0.0274
# [{"variableName": "datasets", "type": "list", "supportedEngines": ["pandas"], "isLocalVariable": false, "rawType": "builtins.list"}, {"variableName": "grid", "type": "ndarray", "supportedEngines": ["pandas"], "isLocalVariable": false, "rawType": "numpy.ndarray"}, {"variableName": "rbf_blob_losses", "type": "list", "supportedEngines": ["pandas"], "isLocalVariable": false, "rawType": "builtins.list"}, {"variableName": "test_losses", "type": "list", "supportedEngines": ["pandas"], "isLocalVariable": false, "rawType": "builtins.list"}]
# Learning rates to try: [0.1     0.15    0.225   0.3375  0.50625]
# epoch : 0 -> Test loss = 0.6082
# epoch : 100 -> Test loss = 0.2198
# epoch : 200 -> Test loss = 0.0682
# epoch : 300 -> Test loss = 0.0491
# epoch : 400 -> Test loss = 0.0420
# epoch : 500 -> Test loss = 0.0359
# epoch : 600 -> Test loss = 0.0332
# epoch : 700 -> Test loss = 0.0304
# epoch : 800 -> Test loss = 0.0282
# epoch : 900 -> Test loss = 0.0270
# epoch : 0 -> Test loss = 0.4364
# epoch : 500 -> Test loss = 0.0439
# epoch : 600 -> Test loss = 0.0389
# epoch : 700 -> Test loss = 0.0359
# epoch : 800 -> Test loss = 0.0328
# epoch : 900 -> Test loss = 0.0303
# Learning rates to try: [0.1     0.15    0.225   0.3375  0.50625]
# epoch : 0 -> Test loss = 0.5921
# epoch : 100 -> Test loss = 0.2432
# epoch : 200 -> Test loss = 0.0782
# epoch : 300 -> Test loss = 0.0518
# epoch : 400 -> Test loss = 0.0434
# epoch : 500 -> Test loss = 0.0384
# epoch : 600 -> Test loss = 0.0352
# epoch : 700 -> Test loss = 0.0320
# epoch : 800 -> Test loss = 0.0301
# epoch : 900 -> Test loss = 0.0287
# epoch : 0 -> Test loss = 0.4446
# epoch : 100 -> Test loss = 0.1207
# epoch : 200 -> Test loss = 0.0523
# epoch : 300 -> Test loss = 0.0393
# epoch : 400 -> Test loss = 0.0354
# epoch : 500 -> Test loss = 0.0310
# epoch : 600 -> Test loss = 0.0286
# epoch : 700 -> Test loss = 0.0270
# epoch : 800 -> Test loss = 0.0256
# epoch : 900 -> Test loss = 0.0245
# epoch : 0 -> Test loss = 0.5590
# epoch : 100 -> Test loss = 0.0774
# epoch : 200 -> Test loss = 0.0465
# epoch : 300 -> Test loss = 0.0362
# epoch : 400 -> Test loss = 0.0312
# epoch : 500 -> Test loss = 0.0280
# epoch : 600 -> Test loss = 0.0261
# epoch : 700 -> Test loss = 0.0241
# epoch : 800 -> Test loss = 0.0231
# epoch : 900 -> Test loss = 0.0222
# epoch : 0 -> Test loss = 0.7184
# epoch : 100 -> Test loss = 0.0463
# epoch : 200 -> Test loss = 0.0283
# epoch : 300 -> Test loss = 0.0246
# epoch : 400 -> Test loss = 0.0220
# epoch : 500 -> Test loss = 0.0203
# epoch : 600 -> Test loss = 0.0190
# epoch : 700 -> Test loss = 0.0180
# epoch : 800 -> Test loss = 0.0172
# epoch : 900 -> Test loss = 0.0163
# epoch : 0 -> Test loss = 1.4241
# epoch : 100 -> Test loss = 0.2041
# epoch : 200 -> Test loss = 0.6528
# epoch : 300 -> Test loss = 0.5984
# epoch : 400 -> Test loss = 0.6324
# epoch : 500 -> Test loss = 0.7966
# epoch : 600 -> Test loss = 0.7524
# epoch : 700 -> Test loss = 0.8425
# epoch : 800 -> Test loss = 0.8822
# epoch : 900 -> Test loss = 0.8607
# [{"variableName": "datasets", "type": "list", "supportedEngines": ["pandas"], "isLocalVariable": false, "rawType": "builtins.list"}, {"variableName": "grid", "type": "ndarray", "supportedEngines": ["pandas"], "isLocalVariable": false, "rawType": "numpy.ndarray"}, {"variableName": "rbf_blob_losses", "type": "list", "supportedEngines": ["pandas"], "isLocalVariable": false, "rawType": "builtins.list"}, {"variableName": "test_losses", "type": "list", "supportedEngines": ["pandas"], "isLocalVariable": false, "rawType": "builtins.list"}]
# [{"variableName": "datasets", "type": "list", "supportedEngines": ["pandas"], "isLocalVariable": false, "rawType": "builtins.list"}, {"variableName": "grid", "type": "ndarray", "supportedEngines": ["pandas"], "isLocalVariable": false, "rawType": "numpy.ndarray"}, {"variableName": "rbf_blob_losses", "type": "list", "supportedEngines": ["pandas"], "isLocalVariable": false, "rawType": "builtins.list"}, {"variableName": "test_losses", "type": "list", "supportedEngines": ["pandas"], "isLocalVariable": false, "rawType": "builtins.list"}]
# Learning rates to try: [0.1 0.2 0.4 0.8 1.6]
# epoch : 0 -> Test loss = 0.6938
# epoch : 100 -> Test loss = 0.4994
# epoch : 200 -> Test loss = 0.5557
# epoch : 300 -> Test loss = 0.5192
# epoch : 400 -> Test loss = 0.4806
# epoch : 500 -> Test loss = 0.4211
# epoch : 600 -> Test loss = 0.3691
# epoch : 700 -> Test loss = 0.3110
# epoch : 800 -> Test loss = 0.2679
# epoch : 900 -> Test loss = 0.2341
# epoch : 0 -> Test loss = 0.5140
# epoch : 100 -> Test loss = 0.4701
# epoch : 400 -> Test loss = 0.0249
# epoch : 500 -> Test loss = 0.0232
# epoch : 600 -> Test loss = 0.0216
# epoch : 700 -> Test loss = 0.0205
# epoch : 800 -> Test loss = 0.0191
# epoch : 900 -> Test loss = 0.0183
# epoch : 0 -> Test loss = 3.7529
# epoch : 100 -> Test loss = 0.4874
# epoch : 200 -> Test loss = 0.4078
# epoch : 300 -> Test loss = 0.6602
# epoch : 400 -> Test loss = 1.1496
# epoch : 500 -> Test loss = 0.9028
# epoch : 600 -> Test loss = 0.9830
# epoch : 700 -> Test loss = 0.6990
# epoch : 800 -> Test loss = 0.8334
# epoch : 900 -> Test loss = 0.7733
# epoch : 0 -> Test loss = 1.1224
# epoch : 100 -> Test loss = 0.1056
# epoch : 200 -> Test loss = 0.0670
# epoch : 300 -> Test loss = 0.0565
# epoch : 400 -> Test loss = 0.0476
# epoch : 500 -> Test loss = 0.0428
# epoch : 600 -> Test loss = 0.0394
# epoch : 700 -> Test loss = 0.0372
# epoch : 800 -> Test loss = 0.0350
# epoch : 900 -> Test loss = 0.0332
# epoch : 0 -> Test loss = 0.7162
# epoch : 100 -> Test loss = 0.3397
# epoch : 200 -> Test loss = 0.4844
# epoch : 300 -> Test loss = 0.5866
# epoch : 400 -> Test loss = 0.5455
# epoch : 500 -> Test loss = 0.5335
# epoch : 600 -> Test loss = 0.4838
# epoch : 700 -> Test loss = 0.1525
# epoch : 800 -> Test loss = 0.1159
# epoch : 900 -> Test loss = 0.1001
# [{"variableName": "datasets", "type": "list", "supportedEngines": ["pandas"], "isLocalVariable": false, "rawType": "builtins.list"}, {"variableName": "grid", "type": "ndarray", "supportedEngines": ["pandas"], "isLocalVariable": false, "rawType": "numpy.ndarray"}, {"variableName": "rbf_blob_losses", "type": "list", "supportedEngines": ["pandas"], "isLocalVariable": false, "rawType": "builtins.list"}, {"variableName": "test_losses", "type": "list", "supportedEngines": ["pandas"], "isLocalVariable": false, "rawType": "builtins.list"}]

# %% [markdown]
# # Neural Networks
#
# We will create a simple 2 layer neural network using the default functions provided by PyTorch

# %%
class NeuralNetwork(torch.nn.Sequential):
    def __init__(self, hidden_layer_size):
        self.name = 'NN'
        self.num_classes = 2
        # ***************************************************
        # INSERT YOUR CODE HERE
        # TODO: Define your neural network model with ReLU
        # HINT: Use torch.nn.Sequential and torch.nn.ReLU
        # ***************************************************
        super().__init__(
            torch.nn.Linear(2, hidden_layer_size),
            torch.nn.ReLU(),
            torch.nn.Linear(hidden_layer_size, self.num_classes),
        )
        
    def init_params(self, train_data):
        ''' No need to do anything since it is taken care of by torch.nn.Sequential'''

# %% [markdown]
# Plot the results while varying the size of the hidden layer in [20, 200, 1000]
#
# What do you observe?

# %%
nn_model = NeuralNetwork(20)
visualize_predictions(datasets, nn_model, optimize)

nn_model = NeuralNetwork(200)
visualize_predictions(datasets, nn_model, optimize)

nn_model = NeuralNetwork(1000)
visualize_predictions(datasets, nn_model, optimize)

# %% [markdown]
# Also try increase the number of layers. How does this effect the classifier learnt?
#
# [This](https://playground.tensorflow.org/) is a cool website where you can play around more with training of neural networks on toy datasets.

# %% [markdown]
# ## Momentum in training neural networks
#
# In the lecture, we have seen how Nesterov momentum can accelerate gradient descent on convex functions. Let's now explore if similar benefits can be achieved on non-convex functions (neural networks in this case) and for *stochastic* gradient descent. It is important to note that theory usually describes convergence on the training objective. In a typical machine learning setting, however, we care about loss on _unseen_ data. For that reason, here, we will always look at loss on the test set.
#
# __Exercise__<br> Add an argument `momentum` to your function `optimize` completed before. Hint: `torch.optim.SGD` also has a `momentum` argument that you can use. This implements heavy ball momentum, which is similar to, but [slightly different](https://dominikschmidt.xyz/nesterov-momentum/) from Nesterov momentum. You can try either variant, but they should have a similar effect.

# %% [markdown]
# ### Hyper-parameter tuning
#
# You will be comparing the SGD optimizers without momentum and with momentum of 0.9 (a common value). To do this fairly, you need to find good learning rates for either variant.

# %% [markdown]
# __Exercise__<br>
# Find a good learning rate for SGD without momentum. You can try different learning rates on an exponential grid (i.e. 0.2, 0.4, 0.8, ...), and record the best test loss in each experiment with `np.min(losses)`. Use `NeuralNetwork(200)` as a model, and use this data:

# %%
dataset = datasets[1]  # and use this dataset, you can try others as well
dataset_name = dataset[0]
train_data = dataset[1]
test_data = dataset[2]
dataset_name
# Out:
# 'Moons'

# %%
plt.xlabel("Learning rate")
plt.ylabel("Best loss seen")

best_loss = None
best_learning_rate = None

grid = 0.1 * 2**np.arange(5)  # This is chosen by trial and error
print("Learning rates to try:", grid)

for learning_rate in grid:
    model = NeuralNetwork(200)
    test_losses = optimize(train_data, test_data, model, lr=learning_rate)
    best_loss_achieved = np.min(test_losses)
    plt.scatter(learning_rate, best_loss_achieved, label=f'lr={learning_rate}', zorder=3, marker='x')
    if best_loss is None or best_loss_achieved < best_loss:
        best_loss = best_loss_achieved
        best_learning_rate = learning_rate
plt.grid()
plt.legend()
plt.plot()
# Out:
# []

# %%
f"The learning rate {best_learning_rate} worked well for SGD without momentum."
# Out:
# 'The learning rate 1.6 worked well for SGD without momentum.'

# %%
plt.xlabel("Learning rate")
plt.ylabel("Best loss seen")

best_loss = None
best_learning_rate_mom = None

# The grid is chosen by trial and error in this case, 
grid = 0.1 * 1.5**np.arange(5)
print("Learning rates to try:", grid)

for learning_rate in grid:
    model = NeuralNetwork(200)
    test_losses = optimize(train_data, test_data, model, lr=learning_rate, momentum=0.9)
    best_loss_achieved = np.min(test_losses)
    plt.scatter(learning_rate, best_loss_achieved, label=f'lr={learning_rate}', zorder=3, marker='x')
    if best_loss is None or best_loss_achieved < best_loss:
        best_loss = best_loss_achieved
        best_learning_rate_mom = learning_rate
plt.grid()
plt.legend()
plt.show()

# %%
f"The learning rate {best_learning_rate_mom} worked well for SGD with 0.9 momentum."
# Out:
# 'The learning rate 0.3375 worked well for SGD with 0.9 momentum.'

# %% [markdown]
# ### Comparing the optimizers
#
# __Exercise__<br>
# Plot test loss curves for both optimizers with the best learning rates you found for each. Do you see a benefit of momentum? How stable are the improvements over different datasets or different initializations? Can you think of ways to make the hyperparameter search procedure more stable?

# %%
model = NeuralNetwork(200)  # reinitialize the model
plt.plot(optimize(train_data, test_data, model, lr=best_learning_rate_mom, momentum=0.9), label="SGD with 0.9 momentum")

model = NeuralNetwork(200)  # reinitialize the model
plt.plot(optimize(train_data, test_data, model, lr=best_learning_rate, momentum=0.0), label="SGD")

plt.ylabel("Test loss")
plt.xlabel("Epochs")
plt.ylim([0, 1])
plt.legend()
plt.grid()
plt.show()
