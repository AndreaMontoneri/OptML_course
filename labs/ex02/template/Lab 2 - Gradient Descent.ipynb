# %%
# Useful starting lines
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# Check the Python version
import sys
if sys.version.startswith("3."):
  print("You are running Python 3. Good job :)")
else:
  print("This notebook requires Python 3.\nIf you are using Google Colab, go to Runtime > Change runtime type and choose Python 3.")
# Out:
# You are running Python 3. Good job :)

# %%
try:
  import google.colab
  IN_COLAB = True
except:
  IN_COLAB = False
if IN_COLAB:
  # Clone the entire repo to access the files.
  #!git clone -l -s https://github.com/epfml/OptML_course.git cloned-repo
  #%cd cloned-repo/labs/ex02/template/
  print('Enlève les #')
else:
  print('Pas sur colab')
# Out:
# Pas sur colab

# %% [markdown]
# # Load the data

# %%
import datetime
from helpers import *

height, weight, gender = load_data(sub_sample=False, add_outlier=False)
x, mean_x, std_x = standardize(height)
b, A = build_model_data(x, weight)

# %%
print('Number of samples n = ', b.shape[0])
print('Dimension of each sample d = ', A.shape[1])
# Out:
# Number of samples n =  10000
# Dimension of each sample d =  2

# %% [markdown]
# # Least Squares Estimation
# Least squares estimation is one of the fundamental machine learning algorithms. Given an $ n \times d $ matrix $A$ and a $ n \times 1$ vector $b$, the goal is to find a vector $x \in \mathbb{R}^d$ which minimizes the objective function $$f(x) = \frac{1}{2n} \sum_{i=1}^{n} (a_i^\top x - b_i)^2 = \frac{1}{2n} \|Ax - b\|^2 $$
#
# In this exercise, we will try to fit $x$ using Least Squares Estimation.
#
# One can see the function is $L$ smooth with $L =\frac1n\|A^T A\|  = \frac1n\|A\|^2$ (Lemma 2.3 for the first equality, and a few manipulations for the second).

# %% [markdown]
# # Computing the Objective Function
# Fill in the `calculate_objective` function below:

# %%
def calculate_objective(Axmb):
    """Calculate the mean squared error for vector Axmb = Ax - b."""
    # ***************************************************
    # INSERT YOUR CODE HERE
    # TODO: compute mean squared error
    # ***************************************************
    norm = np.linalg.norm( Axmb )
    error = np.pow(norm, 2)
    obj = error / ( 2 * Axmb.shape[0] )
    return obj

# %% [markdown]
# # Compute smoothness constant $L$

# %% [markdown]
# To compute the spectral norm of A you can use `np.linalg.norm(A, 2)`

# %%
def calculate_L(b, A):
    """Calculate the smoothness constant for f"""
    # ***************************************************
    # INSERT YOUR CODE HERE
    # TODO: compute ||A.T*A||
    # ***************************************************
    mat = A.T @ A
    norm = np.linalg.norm( mat, 2)
    # ***************************************************
    # INSERT YOUR CODE HERE
    # TODO: compute L = smoothness constant of f
    # ***************************************************
    n = b.shape[0]
    L = norm / n
    return L

# %% [markdown]
# # Gradient Descent

# %% [markdown]
# Please fill in the functions `compute_gradient` below:

# %%
def compute_gradient(b, A, x):
    """Compute the gradient."""
    # ***************************************************
    # INSERT YOUR CODE HERE
    # TODO: compute gradient and objective
    # ***************************************************
    n = b.shape[0]
    Axmb = A@x - b
    grad = (1/n) * (A.T @ Axmb)
    return grad, Axmb

# %% [markdown]
# Please fill in the functions `gradient_descent` below:

# %%
def gradient_descent(b, A, initial_x, max_iters, gamma):
    """Gradient descent algorithm."""
    # Define parameters to store x and objective func. values
    xs = [initial_x]
    objectives = []
    x = initial_x
    for n_iter in range(max_iters):
        # ***************************************************
        # INSERT YOUR CODE HERE
        # TODO: compute gradient and objective function
        # ***************************************************
        grad, Axmb = compute_gradient(b, A, x)
        obj = calculate_objective(Axmb)
        # ***************************************************
        # INSERT YOUR CODE HERE
        # TODO: update x by a gradient descent step
        # ***************************************************
        x = x - gamma * grad
        # store x and objective function value
        xs.append(x)
        objectives.append(obj)
        print("Gradient Descent({bi}/{ti}): objective={l}".format(
              bi=n_iter, ti=max_iters - 1, l=obj))

    return objectives, xs

# %% [markdown]
# Test your gradient descent function with a naive step size through gradient descent demo shown below:

# %%
# from gradient_descent import *
from plots import gradient_descent_visualization

# Define the parameters of the algorithm.
max_iters = 50

gamma = 0.1

# Initialization
x_initial = np.zeros(A.shape[1])

# Start gradient descent.
start_time = datetime.datetime.now()
gradient_objectives_naive, gradient_xs_naive = gradient_descent(b, A, x_initial, max_iters, gamma)
end_time = datetime.datetime.now()

# Print result
exection_time = (end_time - start_time).total_seconds()
print("Gradient Descent: execution time={t:.3f} seconds".format(t=exection_time))
# Out:
# Gradient Descent(0/49): objective=2792.2367127591688
# Gradient Descent(1/49): objective=2264.635056030004
# Gradient Descent(2/49): objective=1837.2777140793803
# Gradient Descent(3/49): objective=1491.1182670993758
# Gradient Descent(4/49): objective=1210.729115045573
# Gradient Descent(5/49): objective=983.6139018819904
# Gradient Descent(6/49): objective=799.6505792194899
# Gradient Descent(7/49): objective=650.6402878628642
# Gradient Descent(8/49): objective=529.941951863998
# Gradient Descent(9/49): objective=432.1762997049165
# Gradient Descent(10/49): objective=352.9861214560593
# Gradient Descent(11/49): objective=288.8420770744858
# Gradient Descent(12/49): objective=236.88540112541085
# Gradient Descent(13/49): objective=194.80049360666032
# Gradient Descent(14/49): objective=160.71171851647227
# Gradient Descent(15/49): objective=133.09981069342015
# Gradient Descent(16/49): objective=110.73416535674792
# Gradient Descent(17/49): objective=92.61799263404335
# Gradient Descent(18/49): objective=77.94389272865276
# Gradient Descent(19/49): objective=66.05787180528634
# Gradient Descent(20/49): objective=56.43019485735945
# Gradient Descent(21/49): objective=48.63177652953873
# Gradient Descent(22/49): objective=42.315057684003975
# Gradient Descent(23/49): objective=37.19851541912083
# Gradient Descent(24/49): objective=33.05411618456545
# Gradient Descent(25/49): objective=29.697152804575616
# Gradient Descent(26/49): objective=26.978012466783838
# Gradient Descent(27/49): objective=24.77550879317249
# Gradient Descent(28/49): objective=22.991480817547313
# Gradient Descent(29/49): objective=21.546418157290898
# Gradient Descent(30/49): objective=20.375917402483225
# Gradient Descent(31/49): objective=19.427811791088978
# Gradient Descent(32/49): objective=18.65984624585966
# Gradient Descent(33/49): objective=18.037794154223914
# Gradient Descent(34/49): objective=17.53393195999896
# Gradient Descent(35/49): objective=17.12580358267675
# Gradient Descent(36/49): objective=16.79521959704575
# Gradient Descent(37/49): objective=16.527446568684653
# Gradient Descent(38/49): objective=16.310550415712157
# Gradient Descent(39/49): objective=16.13486453180442
# Gradient Descent(40/49): objective=15.992558965839171
# Gradient Descent(41/49): objective=15.877291457407319
# Gradient Descent(42/49): objective=15.783924775577509
# Gradient Descent(43/49): objective=15.708297763295361
# Gradient Descent(44/49): objective=15.647039883346835
# Gradient Descent(45/49): objective=15.59742100058852
# Gradient Descent(46/49): objective=15.557229705554285
# Gradient Descent(47/49): objective=15.524674756576557
# Gradient Descent(48/49): objective=15.498305247904602
# Gradient Descent(49/49): objective=15.476945945880317
# Gradient Descent: execution time=0.019 seconds

# %% [markdown]
# Time Visualization

# %%
from ipywidgets import IntSlider, interact
from grid_search import *

def plot_figure(n_iter):
    # Generate grid data for visualization (parameters to be swept and best combination)
    grid_x0, grid_x1 = generate_w(num_intervals=10)
    grid_objectives = grid_search(b, A, grid_x0, grid_x1)
    obj_star, x0_star, x1_star = get_best_parameters(grid_x0, grid_x1, grid_objectives)
    
    fig = gradient_descent_visualization(
        gradient_objectives_naive, gradient_xs_naive, grid_objectives, grid_x0, grid_x1, mean_x, std_x, height, weight, n_iter)
    fig.set_size_inches(10.0, 6.0)

interact(plot_figure, n_iter=IntSlider(min=1, max=len(gradient_xs_naive)))
# Out:
# interactive(children=(IntSlider(value=1, description='n_iter', max=51, min=1), Output()), _dom_classes=('widge…
# <function __main__.plot_figure(n_iter)>

# %% [markdown]
# Try doing gradient descent with a better learning rate

# %%
# Define the parameters of the algorithm.
max_iters = 50

# ***************************************************
# INSERT YOUR CODE HERE
# TODO: a better learning rate using the smoothness of f
# ***************************************************
L = calculate_L(b, A)
gamma = 1/L

# Initialization
x_initial = np.zeros(A.shape[1])

# Start gradient descent.
start_time = datetime.datetime.now()
gradient_objectives, gradient_xs = gradient_descent(b, A, x_initial, max_iters, gamma)
end_time = datetime.datetime.now()

# Print result
exection_time = (end_time - start_time).total_seconds()
print("Gradient Descent: execution time={t:.3f} seconds".format(t=exection_time))
# Out:
# Gradient Descent(0/49): objective=2792.2367127591688
# Gradient Descent(1/49): objective=15.385887868829409
# Gradient Descent(2/49): objective=15.385887868829398
# Gradient Descent(3/49): objective=15.385887868829398
# Gradient Descent(4/49): objective=15.385887868829398
# Gradient Descent(5/49): objective=15.385887868829398
# Gradient Descent(6/49): objective=15.385887868829398
# Gradient Descent(7/49): objective=15.385887868829398
# Gradient Descent(8/49): objective=15.385887868829398
# Gradient Descent(9/49): objective=15.385887868829398
# Gradient Descent(10/49): objective=15.385887868829398
# Gradient Descent(11/49): objective=15.385887868829398
# Gradient Descent(12/49): objective=15.385887868829398
# Gradient Descent(13/49): objective=15.385887868829398
# Gradient Descent(14/49): objective=15.385887868829398
# Gradient Descent(15/49): objective=15.385887868829398
# Gradient Descent(16/49): objective=15.385887868829398
# Gradient Descent(17/49): objective=15.385887868829398
# Gradient Descent(18/49): objective=15.385887868829398
# Gradient Descent(19/49): objective=15.385887868829398
# Gradient Descent(20/49): objective=15.385887868829398
# Gradient Descent(21/49): objective=15.385887868829398
# Gradient Descent(22/49): objective=15.385887868829398
# Gradient Descent(23/49): objective=15.385887868829398
# Gradient Descent(24/49): objective=15.385887868829398
# Gradient Descent(25/49): objective=15.385887868829398
# Gradient Descent(26/49): objective=15.385887868829398
# Gradient Descent(27/49): objective=15.385887868829398
# Gradient Descent(28/49): objective=15.385887868829398
# Gradient Descent(29/49): objective=15.385887868829398
# Gradient Descent(30/49): objective=15.385887868829398
# Gradient Descent(31/49): objective=15.385887868829398
# Gradient Descent(32/49): objective=15.385887868829398
# Gradient Descent(33/49): objective=15.385887868829398
# Gradient Descent(34/49): objective=15.385887868829398
# Gradient Descent(35/49): objective=15.385887868829398
# Gradient Descent(36/49): objective=15.385887868829398
# Gradient Descent(37/49): objective=15.385887868829398
# Gradient Descent(38/49): objective=15.385887868829398
# Gradient Descent(39/49): objective=15.385887868829398
# Gradient Descent(40/49): objective=15.385887868829398
# Gradient Descent(41/49): objective=15.385887868829398
# Gradient Descent(42/49): objective=15.385887868829398
# Gradient Descent(43/49): objective=15.385887868829398
# Gradient Descent(44/49): objective=15.385887868829398
# Gradient Descent(45/49): objective=15.385887868829398
# Gradient Descent(46/49): objective=15.385887868829398
# Gradient Descent(47/49): objective=15.385887868829398
# Gradient Descent(48/49): objective=15.385887868829398
# Gradient Descent(49/49): objective=15.385887868829398
# Gradient Descent: execution time=0.009 seconds

# %% [markdown]
# Time visualization with a better learning rate

# %%
def plot_figure(n_iter):
    # Generate grid data for visualization (parameters to be swept and best combination)
    grid_x0, grid_x1 = generate_w(num_intervals=10)
    grid_objectives = grid_search(b, A, grid_x0, grid_x1)
    obj_star, x0_star, x1_star = get_best_parameters(grid_x0, grid_x1, grid_objectives)
    
    fig = gradient_descent_visualization(
        gradient_objectives, gradient_xs, grid_objectives, grid_x0, grid_x1, mean_x, std_x, height, weight, n_iter)
    fig.set_size_inches(10.0, 6.0)

interact(plot_figure, n_iter=IntSlider(min=1, max=len(gradient_xs)))
# Out:
# interactive(children=(IntSlider(value=1, description='n_iter', max=51, min=1), Output()), _dom_classes=('widge…
# <function __main__.plot_figure(n_iter)>

# %% [markdown]
# # Loading more complex data
# The data is taken from https://archive.ics.uci.edu/ml/datasets/Concrete+Compressive+Strength

# %%
data = np.loadtxt("Concrete_Data.csv",delimiter=",")

A = data[:,:-1]
b = data[:,-1]
A, mean_A, std_A = standardize(A)

# %%
print('Number of samples n = ', b.shape[0])
print('Dimension of each sample d = ', A.shape[1])
# Out:
# Number of samples n =  1030
# Dimension of each sample d =  8

# %% [markdown]
# # Running gradient descent

# %% [markdown]
# ## Assuming bounded gradients
# Assume we are moving in a bounded region $\|x\| \leq 25$ containing all iterates (and we assume $\|x-x^\star\| \leq 25$ as well, for simplicity). Then by $\nabla f(x) = \frac{1}{n}A^\top (Ax - b)$, one can see that $f$ is Lipschitz over that bounded region, with Lipschitz constant $\|\nabla f(x)\| \leq \frac{1}{n} (\|A^\top A\|\|x\| + \|A^\top b\|)$

# %%
# ***************************************************
# INSERT YOUR CODE HERE
# TODO: Compute the bound on the gradient norm
# ***************************************************
n = b.shape[0]
grad_norm_bound = ( np.linalg.norm( A.T @ A, 2) * 25 + np.linalg.norm( A.T @ b ) )/ n


print(grad_norm_bound)
# Out:
# 70.55157320349315

# %% [markdown]
# Fill in the learning rate assuming bounded gradients

# %%
max_iters = 50

# ***************************************************
# INSERT YOUR CODE HERE
# TODO: Compute learning rate based on bounded gradient
# ***************************************************
gamma = 25 / ( grad_norm_bound * np.sqrt( max_iters ) )

# Initialization
x_initial = np.zeros(A.shape[1])

# Start gradient descent.
start_time = datetime.datetime.now()
bd_gradient_objectives, bd_gradient_xs = gradient_descent(b, A, x_initial, max_iters, gamma)
end_time = datetime.datetime.now()


# Print result
exection_time = (end_time - start_time).total_seconds()
print("Gradient Descent: execution time={t:.3f} seconds".format(t=exection_time))

# Averaging the iterates as is the case for bounded gradients case
bd_gradient_objectives_averaged = []
for i in range(len(bd_gradient_xs)):
    if i > 0:
        bd_gradient_xs[i] = (i * bd_gradient_xs[i-1] + bd_gradient_xs[i])/(i + 1)
    grad, err = compute_gradient(b, A, bd_gradient_xs[i])
    obj = calculate_objective(err)
    bd_gradient_objectives_averaged.append(obj)
# Out:
# Gradient Descent(0/49): objective=780.8686016504853
# Gradient Descent(1/49): objective=771.9451380355999
# Gradient Descent(2/49): objective=764.057787368169
# Gradient Descent(3/49): objective=757.0806435792375
# Gradient Descent(4/49): objective=750.9036210736358
# Gradient Descent(5/49): objective=745.4304063496157
# Gradient Descent(6/49): objective=740.5766831862034
# Gradient Descent(7/49): objective=736.2685935205591
# Gradient Descent(8/49): objective=732.4414016205174
# Gradient Descent(9/49): objective=729.0383338025287
# Gradient Descent(10/49): objective=726.0095698886382
# Gradient Descent(11/49): objective=723.3113659504752
# Gradient Descent(12/49): objective=720.9052907468907
# Gradient Descent(13/49): objective=718.7575607023605
# Gradient Descent(14/49): objective=716.8384603602686
# Gradient Descent(15/49): objective=715.1218370326859
# Gradient Descent(16/49): objective=713.5846599014744
# Gradient Descent(17/49): objective=712.2066351425042
# Gradient Descent(18/49): objective=710.9698697774036
# Gradient Descent(19/49): objective=709.8585779325341
# Gradient Descent(20/49): objective=708.8588240256166
# Gradient Descent(21/49): objective=707.9582981259692
# Gradient Descent(22/49): objective=707.1461193609596
# Gradient Descent(23/49): objective=706.4126637831234
# Gradient Descent(24/49): objective=705.7494135812078
# Gradient Descent(25/49): objective=705.1488249244085
# Gradient Descent(26/49): objective=704.6042120808992
# Gradient Descent(27/49): objective=704.1096457569054
# Gradient Descent(28/49): objective=703.659863867327
# Gradient Descent(29/49): objective=703.2501931788438
# Gradient Descent(30/49): objective=702.8764804661782
# Gradient Descent(31/49): objective=702.5350319958109
# Gradient Descent(32/49): objective=702.2225603024712
# Gradient Descent(33/49): objective=701.9361373550963
# Gradient Descent(34/49): objective=701.6731533233592
# Gradient Descent(35/49): objective=701.4312802554624
# Gradient Descent(36/49): objective=701.208440064709
# Gradient Descent(37/49): objective=701.0027762979971
# Gradient Descent(38/49): objective=700.8126292253705
# Gradient Descent(39/49): objective=700.6365138472893
# Gradient Descent(40/49): objective=700.4731004665173
# Gradient Descent(41/49): objective=700.3211975153508
# Gradient Descent(42/49): objective=700.1797363672057
# Gradient Descent(43/49): objective=700.0477578950217
# Gradient Descent(44/49): objective=699.9244005681862
# Gradient Descent(45/49): objective=699.8088899052113
# Gradient Descent(46/49): objective=699.7005291217806
# Gradient Descent(47/49): objective=699.5986908333044
# Gradient Descent(48/49): objective=699.5028096882612
# Gradient Descent(49/49): objective=699.4123758235776
# Gradient Descent: execution time=0.005 seconds

# %% [markdown]
# ## Gradient descent using smoothness
# Fill in the learning rate using smoothness of the function

# %%
max_iters = 50


# ***************************************************
# INSERT YOUR CODE HERE
# TODO: a better learning rate using the smoothness of f
# ***************************************************
gamma = 1 / calculate_L(b, A)

# Initialization
x_initial = np.zeros(A.shape[1])

# Start gradient descent.
start_time = datetime.datetime.now()
gradient_objectives, gradient_xs = gradient_descent(b, A, x_initial, max_iters, gamma)
end_time = datetime.datetime.now()

# Print result
exection_time = (end_time - start_time).total_seconds()
print("Gradient Descent: execution time={t:.3f} seconds".format(t=exection_time))
# Out:
# Gradient Descent(0/49): objective=780.8686016504853
# Gradient Descent(1/49): objective=721.5052560260679
# Gradient Descent(2/49): objective=706.7843584315374
# Gradient Descent(3/49): objective=702.1659603718193
# Gradient Descent(4/49): objective=700.3195706210597
# Gradient Descent(5/49): objective=699.3927282552013
# Gradient Descent(6/49): objective=698.8265138747599
# Gradient Descent(7/49): objective=698.425246037851
# Gradient Descent(8/49): objective=698.1121802865197
# Gradient Descent(9/49): objective=697.8540419775696
# Gradient Descent(10/49): objective=697.6346924802037
# Gradient Descent(11/49): objective=697.4451956987403
# Gradient Descent(12/49): objective=697.2798771098777
# Gradient Descent(13/49): objective=697.134694345026
# Gradient Descent(14/49): objective=697.0065306304227
# Gradient Descent(15/49): objective=696.892866936634
# Gradient Descent(16/49): objective=696.7916143488982
# Gradient Descent(17/49): objective=696.7010172175322
# Gradient Descent(18/49): objective=696.6195897256093
# Gradient Descent(19/49): objective=696.5460698345363
# Gradient Descent(20/49): objective=696.4793834248535
# Gradient Descent(21/49): objective=696.4186151939682
# Gradient Descent(22/49): objective=696.3629844974912
# Gradient Descent(23/49): objective=696.3118250564795
# Gradient Descent(24/49): objective=696.2645678090806
# Gradient Descent(25/49): objective=696.220726375205
# Gradient Descent(26/49): objective=696.1798847171167
# Gradient Descent(27/49): objective=696.141686656003
# Gradient Descent(28/49): objective=696.1058269617541
# Gradient Descent(29/49): objective=696.0720437782061
# Gradient Descent(30/49): objective=696.0401121828639
# Gradient Descent(31/49): objective=696.0098387107206
# Gradient Descent(32/49): objective=695.9810566975378
# Gradient Descent(33/49): objective=695.9536223197188
# Gradient Descent(34/49): objective=695.9274112263599
# Gradient Descent(35/49): objective=695.9023156747346
# Gradient Descent(36/49): objective=695.8782420937702
# Gradient Descent(37/49): objective=695.8551090113991
# Gradient Descent(38/49): objective=695.8328452912638
# Gradient Descent(39/49): objective=695.8113886324365
# Gradient Descent(40/49): objective=695.7906842927656
# Gradient Descent(41/49): objective=695.7706840023488
# Gradient Descent(42/49): objective=695.7513450386713
# Gradient Descent(43/49): objective=695.7326294392003
# Gradient Descent(44/49): objective=695.714503330864
# Gradient Descent(45/49): objective=695.6969363589233
# Gradient Descent(46/49): objective=695.6799012003626
# Gradient Descent(47/49): objective=695.6633731491597
# Gradient Descent(48/49): objective=695.6473297626893
# Gradient Descent(49/49): objective=695.63175056012
# Gradient Descent: execution time=0.003 seconds

# %% [markdown]
# ## Plotting the Evolution of the Objective Function

# %%
plt.figure(figsize=(8, 8))
plt.xlabel('Number of steps')
plt.ylabel('Objective Function')
#plt.yscale("log")
plt.plot(range(len(gradient_objectives)), gradient_objectives,'r', label='gradient descent with 1/L stepsize')
plt.plot(range(len(bd_gradient_objectives)), bd_gradient_objectives,'b', label='gradient descent assuming bounded gradients')
plt.plot(range(len(bd_gradient_objectives_averaged)), bd_gradient_objectives_averaged,'g', label='gradient descent assuming bounded gradients with averaged iterates')
plt.legend(loc='upper right')
plt.show()
